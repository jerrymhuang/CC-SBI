# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
print(os.getcwd())
# Out:
# /home/a_huangm13/Documents/Research/Projects/CC-SBI/playgrounds

# %%
import numpy as np

# %%
geometries = np.load("../data/external/bogo/structures.npy")

# %%
geometries.shape
# Out:
# (102, 3, 3)

# %%
geometries
# Out:
# array([[[10.      , 11.721295,  8.576632],
#         [10.      ,  8.321288,  8.611844],
#         [10.      , 10.      , 10.      ]],
#
#        [[10.      , 11.726019,  8.861514],
#         [10.      ,  8.809794,  9.214937],
#         [10.      , 10.      , 10.      ]],
#
#        [[10.      , 11.889763,  8.746641],
#         [10.      ,  8.688964,  9.130474],
#         [10.      , 10.      , 10.      ]],
#
#        [[10.      , 11.284005,  8.859691],
#         [10.      ,  8.938413,  9.057218],
#         [10.      , 10.      , 10.      ]],
#
#        [[10.      , 11.64699 ,  8.63995 ],
#         [10.      ,  8.397792,  8.67693 ],
#         [10.      , 10.      , 10.      ]],
#
#        [[10.      , 11.447133,  9.050225],
#         [10.      ,  8.602839,  9.083022],
#         [10.      , 10.      , 10.      ]],
#
#        [[10.      , 11.233263,  8.983707],
#         [10.      ,  8.882643,  9.079221],
#         [10.      , 10.      , 10.      ]],
#
# ...

# %%
dft_densities = np.load("../data/external/bogo/dft_densities.npy")

# %%
dft_densities.shape
# Out:
# (102, 125000)

# %%
dft_energies = np.load("../data/external/bogo/dft_energies.npy")

# %%
dft_energies.shape
# Out:
# (102, 1)

# %%
cc_energies = np.load("../data/external/bogo/cc_energies.npy")

# %%
cc_energies.shape
# Out:
# (102, 1)
